# %% [markdown]
# # Recruit restaurant competition

# %% [markdown]
# ## Some thoughts about tasks
# * Convert dates and times
# * Summarise tables: one row per restaurant and day
# * Join with store info
# * Join with actual air visit data
# * Join with holidays data
# * Think about what to do with hpg data...
#
# Remember any features extracted from training tables need to be extractable from submission table.
#
# Remember that we are predicting visits, not reservations.
#
# Check if we have reservation data for some or all submission dates.
#
# Check if the restaurants in the submission list are all included in the training data.

# %% [markdown]
# ## Loading modules

# %%
import pandas as pd
import sklearn as sk

# %% [markdown]
# ## Loading raw data

# %%
air_reserve = pd.read_csv('input/air_reserve.csv')
air_store_info = pd.read_csv('input/air_store_info.csv')
air_visit_data = pd.read_csv('input/air_visit_data.csv')
hpg_reserve = pd.read_csv('input/hpg_reserve.csv')
hpg_store_info = pd.read_csv('input/hpg_store_info.csv')
date_info = pd.read_csv('input/date_info.csv')
sample_submission = pd.read_csv('input/sample_submission.csv')
store_id_relation = pd.read_csv('input/store_id_relation.csv')

# %% [markdown]
# ### Checking submission samples
# What's interesting is that predictions are only required for places in the "air" booking system. Thus, how should we use HPG infos?

# %%
sample_submission.sort_values('id').tail()
# Out:
#                                     id  visitors
# 32014  air_fff68b929994bfbd_2017-05-27         0
# 32015  air_fff68b929994bfbd_2017-05-28         0
# 32016  air_fff68b929994bfbd_2017-05-29         0
# 32017  air_fff68b929994bfbd_2017-05-30         0
# 32018  air_fff68b929994bfbd_2017-05-31         0

# %% [markdown]
# ### A look at date_info table
# Good news: seems like we get the holiday info for every date in the submission table.

# %%
date_info.tail()
# Out:
#     calendar_date day_of_week  holiday_flg
# 512    2017-05-27    Saturday            0
# 513    2017-05-28      Sunday            0
# 514    2017-05-29      Monday            0
# 515    2017-05-30     Tuesday            0
# 516    2017-05-31   Wednesday            0

# %% [markdown]
# ## Data transformation

# %% [markdown]
# ### Extract info from dates
# First, define a little function to extract year, month, day, hour

# %%
def extract_dates(pd_df, target_var, format_str="%Y-%m-%d %H:%M:%S", prefix=None):
    if not prefix:
        prefix = target_var
    pd_df[target_var] = pd.to_datetime(pd_df[target_var], format=format_str)
    pd_df['{0}_year'.format(prefix)]  = pd.DatetimeIndex(pd_df[target_var]).year
    pd_df['{0}_month'.format(prefix)] = pd.DatetimeIndex(pd_df[target_var]).month
    pd_df['{0}_day'.format(prefix)]   = pd.DatetimeIndex(pd_df[target_var]).day
    pd_df['{0}_weekday'.format(prefix)]   = pd.DatetimeIndex(pd_df[target_var]).weekday
    pd_df['{0}_hour'.format(prefix)]  = pd.DatetimeIndex(pd_df[target_var]).hour
    pd_df.drop(target_var, inplace=True, axis=1)
    return pd_df

# %% [markdown]
# #### Extract date infos from hpg_reserve

# %%
hpg_reserve = extract_dates(pd_df = hpg_reserve, target_var = 'visit_datetime', prefix='target')
hpg_reserve = extract_dates(pd_df = hpg_reserve, target_var = 'reserve_datetime')
hpg_reserve.head()
# Out:
#            hpg_store_id  reserve_visitors  target_year  target_month  \
# 0  hpg_c63f6f42e088e50f                 1         2016             1
# 1  hpg_dac72789163a3f47                 3         2016             1
# 2  hpg_c8e24dcf51ca1eb5                 2         2016             1
# 3  hpg_24bb207e5fd49d4a                 5         2016             1
# 4  hpg_25291c542ebb3bc2                13         2016             1
#
#    target_day  target_weekday  target_hour  reserve_datetime_year  \
# 0           1               4           11                   2016
# 1           1               4           13                   2016
# 2           1               4           16                   2016
# 3           1               4           17                   2016
# 4           1               4           17                   2016
#
#    reserve_datetime_month  reserve_datetime_day  reserve_datetime_weekday  \
# 0                       1                     1                         4
# 1                       1                     1                         4
# 2                       1                     1                         4
# 3                       1                     1                         4
# 4                       1                     1                         4
#
#    reserve_datetime_hour
# 0                      9
# 1                      6
# 2                     14
# 3                     11
# 4                      3

# %% [markdown]
# #### Now air reservations

# %%
air_reserve = extract_dates(pd_df = air_reserve, target_var = 'visit_datetime', prefix='target')
air_reserve = extract_dates(pd_df = air_reserve, target_var = 'reserve_datetime')
air_reserve.pivot_table(columns='reserve_datetime_weekday')
# Out:
# reserve_datetime_weekday            0            1            2            3  \
# reserve_datetime_day        16.150203    15.994182    14.879658    14.743219
# reserve_datetime_hour       17.037157    16.793863    16.767664    16.802785
# reserve_datetime_month       5.654972     5.598601     5.530238     5.555461
# reserve_datetime_year     2016.460977  2016.476138  2016.491957  2016.494582
# reserve_visitors             4.759144     4.793032     4.634290     4.526762
# target_day                  16.387161    16.476138    15.985543    16.036645
# target_hour                 18.194576    18.117268    18.125365    18.110593
# target_month                 5.663515     5.580453     5.490871     5.511920
# target_weekday               2.323878     2.812703     3.218353     3.581598
# target_year               2016.487020  2016.501558  2016.515509  2016.516845
#
# reserve_datetime_weekday            4            5            6
# reserve_datetime_day        15.309101    15.273579    15.644157
# reserve_datetime_hour       16.423291    15.854328    15.795848
# reserve_datetime_month       5.500857     5.372820     5.540127
# reserve_datetime_year     2016.488581  2016.506702  2016.486103
# reserve_visitors             4.390988     3.977955     4.123563
# target_day                  16.128043    16.063953    16.401607
# target_hour                 18.087511    17.932817    17.648510
# target_month                 5.446334     5.328569     5.535328
# target_weekday               3.846993     4.299822     4.086840
# target_year               2016.510459  2016.525517  2016.508092

# %% [markdown]
# #### Now datainfo

# %%
date_info = extract_dates(pd_df = date_info, target_var = 'calendar_date', format_str="%Y-%m-%d", prefix='date')
date_info.drop('date_hour', inplace=True, axis=1)
date_info.pivot_table(columns='day_of_week')
# Out:
# day_of_week        Friday       Monday     Saturday       Sunday     Thursday  \
# date_day        15.567568    15.675676    15.743243    15.918919    15.602740
# date_month       5.513514     5.445946     5.540541     5.405405     5.547945
# date_weekday     4.000000     0.000000     5.000000     6.000000     3.000000
# date_year     2016.283784  2016.297297  2016.283784  2016.297297  2016.287671
# holiday_flg      0.067568     0.121622     0.067568     0.054054     0.095890
#
# day_of_week       Tuesday    Wednesday
# date_day        15.864865    15.648649
# date_month       5.472973     5.513514
# date_weekday     1.000000     2.000000
# date_year     2016.297297  2016.297297
# holiday_flg      0.027027     0.040541

# %% [markdown]
# ### Extract dates and location from submission table

# %%
# First, split up id column
x = sample_submission.join(sample_submission['id'].str.split('_', 1, expand=True).rename(columns={0:'id1', 1:'id2'}))
x['id2'], x['date'] = x['id2'].str.split('_', 1).str
x['air_store_id'] = x[['id1', 'id2']].apply(lambda x: '_'.join(x), axis=1)
x.rename(columns={'id1':'store_type'}, inplace=True)
x.drop('id2', inplace=True, axis=1)
x = extract_dates(pd_df = x, target_var = 'date', format_str="%Y-%m-%d", prefix='target')
x.drop('target_hour', inplace=True, axis=1)
x['test'] = 1
x.head()
sample_submission = x
sample_submission.head()
# Out:
#                                 id  visitors store_type          air_store_id  \
# 0  air_00a91d42b08b08d9_2017-04-23         0        air  air_00a91d42b08b08d9
# 1  air_00a91d42b08b08d9_2017-04-24         0        air  air_00a91d42b08b08d9
# 2  air_00a91d42b08b08d9_2017-04-25         0        air  air_00a91d42b08b08d9
# 3  air_00a91d42b08b08d9_2017-04-26         0        air  air_00a91d42b08b08d9
# 4  air_00a91d42b08b08d9_2017-04-27         0        air  air_00a91d42b08b08d9
#
#    target_year  target_month  target_day  target_weekday  test
# 0         2017             4          23               6     1
# 1         2017             4          24               0     1
# 2         2017             4          25               1     1
# 3         2017             4          26               2     1
# 4         2017             4          27               3     1

# %%
sample_submission.pivot_table(columns='store_type')
# Out:
# store_type              air
# target_day        18.153846
# target_month       4.794872
# target_weekday     2.923077
# target_year     2017.000000
# test               1.000000
# visitors           0.000000

# %% [markdown]
# ### Extract date info from air_visit_data

# %%
air_visit_data = extract_dates(pd_df = air_visit_data, target_var = 'visit_date', 
                               format_str="%Y-%m-%d", prefix='target')
air_visit_data.drop('target_hour', axis=1, inplace=True)
air_visit_data['id'] = 0
air_visit_data['test'] = 0
air_visit_data['store_type'] = 'air'
air_visit_data.head()
# Out:
#            air_store_id  visitors  target_year  target_month  target_day  \
# 0  air_ba937bf13d40fb24        25         2016             1          13
# 1  air_ba937bf13d40fb24        32         2016             1          14
# 2  air_ba937bf13d40fb24        29         2016             1          15
# 3  air_ba937bf13d40fb24        22         2016             1          16
# 4  air_ba937bf13d40fb24         6         2016             1          18
#
#    target_weekday  id  test store_type
# 0               2   0     0        air
# 1               3   0     0        air
# 2               4   0     0        air
# 3               5   0     0        air
# 4               0   0     0        air

# %% [markdown]
# ### Constructing main table
# Concatenate edited submission table with air_visit_data

# %%
main_tbl = pd.concat([air_visit_data, sample_submission])
main_tbl.head()
# Out:
#            air_store_id id store_type  target_day  target_month  \
# 0  air_ba937bf13d40fb24  0        air          13             1
# 1  air_ba937bf13d40fb24  0        air          14             1
# 2  air_ba937bf13d40fb24  0        air          15             1
# 3  air_ba937bf13d40fb24  0        air          16             1
# 4  air_ba937bf13d40fb24  0        air          18             1
#
#    target_weekday  target_year  test  visitors
# 0               2         2016     0        25
# 1               3         2016     0        32
# 2               4         2016     0        29
# 3               5         2016     0        22
# 4               0         2016     0         6

# %%
main_tbl.pivot_table(columns='test')
# Out:
# test                      0            1
# target_day        15.591830    18.153846
# target_month       6.208200     4.794872
# target_weekday     3.019678     2.923077
# target_year     2016.307697  2017.000000
# visitors          20.973761     0.000000

# %% [markdown]
# ## Prepare baseline submission
# Ie. average number of visitors for each restaurant.

# %%
def prepare_submission(main_tbl, fpath=None):
    sub_tbl = main_tbl.loc[main_tbl['test'] == 1][['id', 'visitors']]
    if fpath:
        sub_tbl.to_csv(fpath, index=False)
    return sub_tbl

# %%
# Get mean visitor numbers for train data
visitors_mean = main_tbl.loc[main_tbl['test'] == 0].visitors.mean()
baseline_sub = main_tbl.loc[main_tbl['test'] == 1][['id', 'visitors']]
baseline_sub.visitors = visitors_mean
baseline_sub.to_csv('submissions/baseline.csv', index=False)

# %% [markdown]
# ## Merge with additional infos

# %% [markdown]
# ### Merge with store info

# %%
air_store_info.head()
# Out:
#            air_store_id  air_genre_name                 air_area_name  \
# 0  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 1  air_7cc17a324ae5c7dc  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 2  air_fee8dcf4d619598e  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 3  air_a17f0778617c76e2  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 4  air_83db5aff8f50478e  Italian/French  Tōkyō-to Minato-ku Shibakōen
#
#     latitude   longitude
# 0  34.695124  135.197852
# 1  34.695124  135.197852
# 2  34.695124  135.197852
# 3  34.695124  135.197852
# 4  35.658068  139.751599

# %%
main_tbl_merge = pd.merge(main_tbl, air_store_info, on='air_store_id')
main_tbl_merge.head()
# Out:
#            air_store_id id store_type  target_day  target_month  \
# 0  air_ba937bf13d40fb24  0        air          13             1
# 1  air_ba937bf13d40fb24  0        air          14             1
# 2  air_ba937bf13d40fb24  0        air          15             1
# 3  air_ba937bf13d40fb24  0        air          16             1
# 4  air_ba937bf13d40fb24  0        air          18             1
#
#    target_weekday  target_year  test  visitors air_genre_name  \
# 0               2         2016     0        25     Dining bar
# 1               3         2016     0        32     Dining bar
# 2               4         2016     0        29     Dining bar
# 3               5         2016     0        22     Dining bar
# 4               0         2016     0         6     Dining bar
#
#                   air_area_name   latitude   longitude
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599

# %%
main_tbl_merge.describe()
# Out:
#           target_day   target_month  target_weekday    target_year  \
# count  284127.000000  284127.000000   284127.000000  284127.000000
# mean       15.880550       6.048929        3.008792    2016.385715
# std         8.756654       3.498014        1.937996       0.486765
# min         1.000000       1.000000        0.000000    2016.000000
# 25%         8.000000       3.000000        1.000000    2016.000000
# 50%        16.000000       5.000000        3.000000    2016.000000
# 75%        23.000000       9.000000        5.000000    2017.000000
# max        31.000000      12.000000        6.000000    2017.000000
#
#                 test       visitors       latitude      longitude
# count  284127.000000  284127.000000  284127.000000  284127.000000
# mean        0.112693      18.610174      35.615446     137.363917
# std         0.316217      17.121342       2.046084       3.668228
# min         0.000000       0.000000      33.211967     130.195555
# 25%         0.000000       6.000000      34.692337     135.341564
# 50%         0.000000      15.000000      35.658068     139.671958
# 75%         0.000000      27.000000      35.694003     139.751599
# max         1.000000     877.000000      44.020632     144.273398

# %% [markdown]
# ### Merge with holiday info

# %%
date_info_merge = date_info
date_info_merge['date_id'] = date_info_merge[['date_year', 'date_month', 'date_day']].astype(str).apply(lambda x: '_'.join((x)), axis=1)
date_info_merge = date_info_merge[['holiday_flg', 'date_id']]
date_info_merge.head()
# Out:
#    holiday_flg   date_id
# 0            1  2016_1_1
# 1            1  2016_1_2
# 2            1  2016_1_3
# 3            0  2016_1_4
# 4            0  2016_1_5

# %%
main_tbl_merge2 = main_tbl_merge
main_tbl_merge2['date_id'] = main_tbl_merge2[['target_year', 'target_month', 'target_day']].astype(str).apply(lambda x: '_'.join((x)), axis=1)

main_tbl_merge2.head()
# Out:
#            air_store_id id store_type  target_day  target_month  \
# 0  air_ba937bf13d40fb24  0        air          13             1
# 1  air_ba937bf13d40fb24  0        air          14             1
# 2  air_ba937bf13d40fb24  0        air          15             1
# 3  air_ba937bf13d40fb24  0        air          16             1
# 4  air_ba937bf13d40fb24  0        air          18             1
#
#    target_weekday  target_year  test  visitors air_genre_name  \
# 0               2         2016     0        25     Dining bar
# 1               3         2016     0        32     Dining bar
# 2               4         2016     0        29     Dining bar
# 3               5         2016     0        22     Dining bar
# 4               0         2016     0         6     Dining bar
#
#                   air_area_name   latitude   longitude    date_id
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599  2016_1_13
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599  2016_1_14
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599  2016_1_15
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599  2016_1_16
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599  2016_1_18

# %%
main_tbl_merge = pd.merge(left=main_tbl_merge2, right=date_info_merge, on='date_id')
main_tbl_merge.describe()
# Out:
#           target_day   target_month  target_weekday    target_year  \
# count  284127.000000  284127.000000   284127.000000  284127.000000
# mean       15.880550       6.048929        3.008792    2016.385715
# std         8.756654       3.498014        1.937996       0.486765
# min         1.000000       1.000000        0.000000    2016.000000
# 25%         8.000000       3.000000        1.000000    2016.000000
# 50%        16.000000       5.000000        3.000000    2016.000000
# 75%        23.000000       9.000000        5.000000    2017.000000
# max        31.000000      12.000000        6.000000    2017.000000
#
#                 test       visitors       latitude      longitude  \
# count  284127.000000  284127.000000  284127.000000  284127.000000
# mean        0.112693      18.610174      35.615446     137.363917
# std         0.316217      17.121342       2.046084       3.668228
# min         0.000000       0.000000      33.211967     130.195555
# 25%         0.000000       6.000000      34.692337     135.341564
# 50%         0.000000      15.000000      35.658068     139.671958
# 75%         0.000000      27.000000      35.694003     139.751599
# max         1.000000     877.000000      44.020632     144.273398
#
#          holiday_flg
# count  284127.000000
# mean        0.056520
# std         0.230924
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %% [markdown]
# ### Save current stage to disk

# %%
main_tbl_merge.to_csv('output/main_tbl.csv')

# %% [markdown]
# ## First simple modelling attempt
#
# First perform one hot encoding on data.

# %%
import pandas as pd

model_data = pd.read_csv('output/main_tbl.csv')
# Out:
# /anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
target_cols = ['target_day', 'target_month', 'target_weekday', 'target_year', 'latitude', 'longitude', 'holiday_flg',
              'test', 'visitors', 'air_genre_name', 'air_area_name']
target_cols = ['target_day', 'target_month', 'target_weekday', 'target_year', 'latitude', 'longitude', 'holiday_flg',
              'test', 'visitors']
X = model_data[target_cols]
print X.shape
#X = model_data[target_cols]
#X = pd.get_dummies(X, columns=['air_genre_name', 'air_area_name'])
#X.head()
# Out:
# (284127, 9)

# %%
from sklearn.linear_model import LogisticRegression

target_cols_fit = [col for col in X.columns if not col in ['visitors', 'test']] 

mod = LogisticRegression(verbose=1, solver='sag')

X_train = X.loc[X['test'] == 0]
X_train
mod.fit(X=X_train[target_cols_fit], y=X_train['visitors'])
# Out:
# max_iter reached after 16 seconds
# /anaconda2/lib/python2.7/site-packages/sklearn/linear_model/sag.py:326: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# max_iter reached after 30 seconds
# max_iter reached after 18 seconds
# max_iter reached after 18 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 18 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 15 seconds
# max_iter reached after 18 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 15 seconds
# max_iter reached after 18 seconds
# max_iter reached after 24 seconds
# max_iter reached after 18 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 18 seconds
# max_iter reached after 23 seconds
# max_iter reached after 24 seconds
# max_iter reached after 18 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 39 seconds
# max_iter reached after 5912 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 19 seconds
# max_iter reached after 17 seconds
# max_iter reached after 18 seconds
# max_iter reached after 18 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# convergence after 3 epochs took 0 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 24 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 20 seconds
# max_iter reached after 23 seconds
# max_iter reached after 21 seconds
# max_iter reached after 17 seconds
# max_iter reached after 15 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 16 seconds
# max_iter reached after 17 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# max_iter reached after 15 seconds
# max_iter reached after 16 seconds
# max_iter reached after 15 seconds
# [Parallel(n_jobs=1)]: Done 204 out of 204 | elapsed: 154.8min finished
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='sag', tol=0.0001,
#           verbose=1, warm_start=False)

# %%
X_test = X.loc[X['test'] == 1]

mod.predict(X_test[target_cols_fit])
